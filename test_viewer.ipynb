# %%
# %reload_ext autoreload
# %autoreload

# %%
from set_env import set_env
import os
import sys
set_env()
sys.path.insert(1, '../snorkel')
# os.environ['SNORKELHOME'] = '/home/pyke/workspace/snorkel'
import cPickle
from snorkel import SnorkelSession
from snorkel.models import candidate_subclass
from snorkel.viewer import SentenceNgramViewer

session = SnorkelSession()

GenePhenoPair = candidate_subclass('GenePhenoPair',['gene', 'pheno'])

# %%
svs = []
for i in range(0,10):
    split_cands = session.query(GenePhenoPair).filter(GenePhenoPair.split==i).all()
    #cand_extractor.apply(test_sents, split=2)#, parallelism=8)
    #test_cands = session.query(GenePhenoPair).filter(GenePhenoPair.split==2).all()

    #print "Number of train candidates:", len(train_cands)
    print "Number of candidates in split {}:".format(i), len(split_cands)
    #print "Number of test candidates:", len(test_cands)

    # NOTE: This if-then statement is only to avoid opening the viewer during automated testing of this notebook
    # You should ignore this!
    sv = SentenceNgramViewer(split_cands, session, n_per_page=8, height=900, annotator_name = 'gold')
    svs.append(sv)
# Out:
# Number of candidates in split 0: 0
# Number of candidates in split 1: 9
# Number of candidates in split 2: 1
# Number of candidates in split 3: 112
# Number of candidates in split 4: 0
# Number of candidates in split 5: 188
# Number of candidates in split 6: 386
# Number of candidates in split 7: 67
# Number of candidates in split 8: 195
# Number of candidates in split 9: 0

# %%
# Change the number below to view a different document. Indexing starts at 0.
svs[1]
