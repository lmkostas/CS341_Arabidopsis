# %% [markdown]
# # Tagging genes with ddlite: learning and labeling function iteration
#
# ## Introduction
# In this example **ddlite** app, we'll build a gene tagger from scratch. Domain-specific tagging systems take months or years to develop. They use hand-crafted model circuitry and accurate, hand-labeled training data. We'll start to build a pretty good one in a few minutes with none of those things. The generalized extraction and learning utilities provided by ddlite will allow us to turn a sampling of article abstracts and some basic domain knowledge into an automated tagging system. Specifically, we want an accurate tagger for genes in academic articles. We have comprehensive dictionaries of genes, but applying a simple matching rule might yield a lot of false positives. For example, "p53" might get tagged as a gene if it refers to a page number. Our goal is to use distant supervision to improve precision.
#
# Here's the pipeline we'll follow:
#
# 1. Obtain and parse input data (relevant article abstracts from PubMed)
# 2. Extract candidates for tagging
# 3. Generate features
# 4. Create a test set
# 5. Write labeling functions
# 6. Learn the tagging model
# 7. Iterate on labeling functions
#
# Parts 3 through 7 are covered in this notebook. It requires candidates extracted from `GeneTaggerExample_Extraction.ipynb`, which covers parts 1 and 2.

# %%
# %reload_ext autoreload
# %autoreload 2

import os
import sys
import cPickle
import numpy as np
import matplotlib
# print(os.environ['SNORKELDB'])
# Use production DB
from set_env import set_env
set_env() 
sys.path.insert(1, '../snorkel')

# Must set SNORKELDB before importing SnorkelSession
from snorkel import SnorkelSession
from snorkel.parser import TextDocPreprocessor
from snorkel.parser import CorpusParser
from snorkel.models import Document, Sentence, candidate_subclass
from snorkel.viewer import SentenceNgramViewer
session = SnorkelSession()

#np.random.seed(seed=1701)

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (18,6)

# %% [markdown]
# ## Loading candidate extractions
# First, we'll load in the candidates that we created in the last notebook. We can construct an docs object with the file.

# %%
PhenoPair = candidate_subclass('Phenotypes', ['descriptor', 'entity'])

docs = session.query(PhenoPair).filter(PhenoPair.split == 0).all()  #should edit split to be 1. 

print "Documents:", session.query(Document).count()
print "Sentences:", session.query(Sentence).count()

##Once we get all the labels, for loop through all docs and split into train, dev, test. 

print 'Document set:\t{0} candidates'.format(len(docs))
# Out:
# Documents: 400
# Sentences: 95656
# Document set:	39176 candidates

# %%
docs = session.query(PhenoPair).filter(PhenoPair.split == 0).all()
print 'Document set:\t{0} candidates'.format(len(docs))
# Out:
# Document set:	39176 candidates

# %%
from snorkel.models.context import TemporaryContext
import re

print docs
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Make Labeling Functions

# %%
import re
import os
from snorkel.lf_helpers import (
    get_left_tokens,
    get_between_tokens,
    get_right_tokens,
    contains_token,
    get_text_between,
    get_text_splits,
    get_tagged_text,
    is_inverted,
    get_tagged_text,
    rule_regex_search_tagged_text,
    rule_regex_search_btw_AB,
    rule_regex_search_btw_BA,
    rule_regex_search_before_A,
    rule_regex_search_before_B,
    
)


def LF_mutant(c):
    return 1 if ('mutant' in get_right_tokens(c, attrib='lemmas')) or ('mutant' in get_left_tokens(c, attrib='lemmas')) else 0
def LF_variant(c):
    return 1 if ('variant' in get_right_tokens(c, attrib='lemmas')) or ('variant' in get_left_tokens(c, attrib='lemmas')) else 0
def LF_express(c):
    return 1 if ('express' in get_right_tokens(c, attrib='lemmas')) or ('express' in get_left_tokens(c, attrib='lemmas')) else 0  
def LF_JJ(c):
    return 1 if 'JJ' in get_right_tokens(c, attrib='pos_tags') else 0
def LF_IN(c):
    return 1 if 'IN' in get_right_tokens(c, window=1, attrib='pos_tags') else 0
def LF_dna(c):
    return -1 if contains_token(c, 'DNA', attrib='words') else 0
def LF_rna(c):
    return -1 if contains_token(c, 'RNA', attrib='words') else 0
def LF_snp(c):
    return -1 if contains_token(c, 'SNP', attrib='words') else 0
def LF_protein(c):
    return -1 if 'protein' in get_left_tokens(c, attrib='lemmas') else 0
def LF_LRB(c):
    return -1 if '-LRB-' in get_right_tokens(c, window=1, attrib='pos_tags') else 0
def LF_RRB(c):
    return -1 if '-RRB-' in get_right_tokens(c, window=1, attrib='pos_tags') else 0    
def LF_NNP(c):
    return -1 if contains_token(c, 'NNP', attrib='pos_tags') else 0
def lfdistBtw0(c):
    return 1 if len(get_between_tokens(c, attrib="words")) == 0 else 0
def lfdistBtw(c):
    return 1 if len(get_between_tokens(c, attrib="words")) < 3 else 0
def lfdistBtwNeg(c):
    return -1 if len(get_between_tokens(c, attrib="words")) > 4 else 0
def lfdistBtwNeg2(c):
    return -1 if len(get_between_tokens(c, attrib="words")) > 8 else 0

action_link_words = set(['affect', 'lead', 'led', 'show', 'display', 'exhibit', 'cause', 'result in'])
mutant_words = set(['mutant', 'mutation', 'plant', 'line', 'phenotype', 'seedlings', 'variant'])
helper_vbs = set(['is', 'was', 'are', 'were', 'become', 'became'])
tester_words = set(['sequence', 'published', 'diagram', 'hypothesis', 'hypothesize', 'aim', 'goal', 'understand', 'examine', 'we', 'our', 'experiment', 'test', 'study', 'design', 'analyze', 'analysis', 'results', 'research'])
neg_words = set(['strategy', 'public', 'examine', 'measure', 'subject', 'statistic', 'instance'])

def lfnegWords(c):
    for word in neg_words:
        if contains_token(c, word, attrib='lemmas'): return -1
    return 0    

def resultsAlone(c):
    return -1 if (len(c[0].get_attrib_tokens('words')) == 1 and contains_token(c[0], 'result', attrib='lemmas')) or (len(c[1].get_attrib_tokens('lemmas')) == 1 and contains_token(c[1], 'result', attrib='lemmas')) else 0

def lfLenCand(c):
    return -1 if len(c[0].get_attrib_tokens('words')) == 1 or len(c[1].get_attrib_tokens('words')) == 1 else 0

def lf1(c):
    return 1 if 'in' in get_between_tokens(c, attrib='words') else 0

def lf2(c):
    return 1 if len(action_link_words.intersection(set(get_between_tokens(c, attrib='lemmas')))) > 0 else 0

def lf2a(c):
    for aw in action_link_words:
        if contains_token(c[1], aw, attrib='lemmas'): return 1
    return 0

def lf3(c):
    return 1 if contains_token(c[0], 'JJR', attrib='pos_tags') else 0

def lf4(c):
    return 1 if contains_token(c, r'fold') or contains_token(c, r'\d+(\.\d+_)?%') or contains_token(c, 'percent') else 0

def lf5(c):
    return 1 if len(mutant_words.intersection(set(get_left_tokens(c, attrib='lemmas')))) > 0 or len(mutant_words.intersection(set(get_right_tokens(c, attrib='lemmas')))) > 0 else 0

def lf6(c):
    return 1 if len(helper_vbs.intersection(set(get_between_tokens(c, attrib='lemmas', n_max=3)))) > 0 else 0

def lf7(c):
    return -1 if 'not' in get_between_tokens(c) else 0

def lf8(c):
    return -1 if 'not' in get_left_tokens(c[0]) or 'not' in get_left_tokens(c[1]) else 0

def lf9(c):
    return -1 if 'level' in get_left_tokens(c[0], attrib='lemmas', n_max=2) or 'level' in get_right_tokens(c[0], attrib='lemmas', n_max=2) else 0

def lf10(c):
    return -1 if 'transcript' in get_left_tokens(c[0], attrib='lemmas', n_max=3) or 'transcript' in get_right_tokens(c[0], attrib='lemmas', n_max=2) else 0

def lf11(c):
    return -1 if not contains_token(c, 'JJR', attrib='pos_tags') and not contains_token(c, 'JJ', attrib='pos_tags') and not contains_token(c[1], 'VBN', attrib='pos_tags') else 0

def inverted(c):
    return 1 if is_inverted(c) else 0

def lf12(c):
    return 1 if inverted(c) and lf1(c) else 0

def lf13(c):
    return 1 if inverted(c) and 'IN' in get_between_tokens(c, attrib='pos_tags', n_max=4) else 0

def lf14(c):
    return 1 if contains_token(c, 'phenotype', attrib='lemmas') else 0

def lf15(c):
    return -1 if 'protein' in get_left_tokens(c[0], attrib='lemmas') or 'protein' in get_right_tokens(c[0], attrib='lemmas') else 0

def lf16(c):
    return -1 if 'activity' in get_left_tokens(c[0], attrib='lemmas', n_max=2) or 'level' in get_right_tokens(c[0], attrib='lemmas', n_max=1) else 0

def lf17(c):
    return -1 if len(tester_words.intersection(set(get_tagged_text(c).split()))) > 0 else 0

# def LF_gene_dp(c):
#     return 1 if 'gene' in get_left_tokens(c[0], window=2, attrib='lemmas') else 0
# def LF_genotype_dp(c):
#     return 1 if 'genotype' in get_left_tokens(c[0], window=2, attrib='lemmas') else 0
def LF_phenotype_dp(c):
    return 1 if 'phenotype' in get_right_tokens(c[1], window=2, attrib='lemmas') else 0
def LF_mutation(c):
    return 1 if ('mutation' in get_right_tokens(c[0], window=2, attrib='lemmas') or 'mutant' in get_right_tokens(c[0], window=2, attrib='lemmas') or 'mutations' in get_right_tokens(c[0], window=2, attrib='lemmas')) else 0

def LF_pheno(c):
    return 1 if contains_token(c, 'phenotype', attrib='words') else 0

def LF_dev_dp(c):
    return -1 if 'development' in get_right_tokens(c[1], window=2, attrib='lemmas')  else 0
def LF_protein_dp(c):
    return -1 if 'protein' in get_left_tokens(c[1], window=2, attrib='lemmas') or 'protein' in get_right_tokens(c[1], window=2, attrib='lemmas') else 0
def LF_network_dp(c):
    return -1 if 'network' in get_right_tokens(c[1], window=2, attrib='lemmas') else 0
def LF_JJ_dp(c):
    return -1 if 'JJ' in get_right_tokens(c[1], window=2, attrib='pos_tags') else 0

def lf_helpers(c):
    return 1 if any(word in get_left_tokens(c, window=2, attrib='words') for word in ['had', 'has', 'was', 'have', 'showed', 'were', 'is', 'are', 'results']) else 0

adj_words = set(['increase', 'lower', 'reduce', 'higher', 'less', 'more', 'elevate', 'decrease', 'insensitive', 'absence', 'inhibit', 'double',])
def lf_adjwords(c):
    for aw in adj_words:
        if contains_token(c, aw, attrib='lemmas'): return 1
    return 0
    
stats_words = set(['statistically', 'significant', 'quantitative', 'real-time', 'generated', 'exposed', 'stratified'])
def lf_statswords(c):
    for aw in stats_words:
        if contains_token(c, aw, attrib='lemmas'): return -1
    return 0
   
def lf_proteinIn(c):
    return -1 if 'protein' in get_left_tokens(c[1], attrib='lemmas') or 'protein' in get_right_tokens(c[1], attrib='lemmas') or contains_token(c[1], 'protein', attrib='lemmas') else 0

def lf18(c):
    return 1 if 'mutant' in get_tagged_text(c).split() or 'mutation' in get_text_splits(c) else 0

# def lf19(c):
#     lemmas = c[0].get_attrib_tokens('lemmas')
#     poses = c[0].get_attrib_tokens('pos_tags')
#     for i, w in enumerate(poses):
#         if w in ['NN', 'NNS', 'NNP', 'NNPS'] and not re.match(r'\w+(ion|ment|vity)', lemmas[i]):
#             return -1
#     return 0

def lf20(c):
    lemmas = c[0].get_attrib_tokens('lemmas')
    poses = c[0].get_attrib_tokens('pos_tags')
    result = 0
    for i, w in enumerate(lemmas):
        if w in ['NN', 'NNS', 'NNP', 'NNPS'] and not re.match(r'\w+(ion|ment|vity)', lemmas[i]):
            result = 0
        elif re.match(r'\w+(ion|ment|vity)', lemmas[i]):
            result = -1
    return result

def lf21(c):
    return rule_regex_search_btw_BA(c, '.* in .*', 1)

def lf22(c):
    return -1 if 'expression' in get_right_tokens(c[0], attrib='lemmas', window=2) or 'expression' in get_left_tokens(c[0], attrib='lemmas', window=2) else 0
    
def lf23(c):
    return -1 if not inverted(c) and len(helper_vbs.intersection(set(get_right_tokens(c[0], window = 1, attrib='lemmas')))) > 0 and ('VBN' == c[0].get_attrib_tokens('pos_tags')[0] or ('VBN' == c[0].get_attrib_tokens('pos_tags')[1] and 'RB' == c[0].get_attrib_tokens('pos_tags')[0])) else 0

def lf24(c):
    return -1 if not contains_token(c[0], 'VB', attrib='pos_tags') and not contains_token(c[0], 'VBZ', attrib='pos_tags') and not contains_token(c[0], 'VBD', attrib='pos_tags') else 0

def lf25(c):
    return -1 if 'IN' == c[0].get_attrib_tokens('pos_tags')[0] or 'TO' == c[0].get_attrib_tokens('pos_tags')[0] else 0

def lf26(c):
    if len(c[0].get_attrib_tokens('pos_tags')) < 2:
        return 0
    return -1 if 'JJR' == c[0].get_attrib_tokens('pos_tags')[0] and len(set(['NN', 'NNS', 'NNP', 'NNPS']).intersection(set(c[0].get_attrib_tokens('pos_tags')[1]))) == 0 else 0

def lf27(c):
    hasNoNoun = len(set(['NN', 'NNS', 'NNP', 'NNPS']).intersection(set(c[0].get_attrib_tokens('pos_tags')[0]))) == 0
    return -1 if (len(c[0]) < 3 and hasNoNoun) else 0
                  
def lf28(c):
    if len(c[0].get_attrib_tokens('pos_tags')) == 0:
        return 0
    if len(c[0].get_attrib_tokens('lemmas')) < 2:
        return 0
    lastWordAdj = True if c[0].get_attrib_tokens('pos_tags')[-1] in set(['JJ', 'JJR']) else False
    nextLastVrb = True if c[0].get_attrib_tokens('lemmas')[-2] in helper_vbs else False
    return -1 if not nextLastVrb and lastWordAdj else 0              
    
def lf29(c):                  #if pheno ends in VBG, its bad
    return -1 if c[0].get_attrib_tokens('pos_tags')[-1] == 'VBG' else 0

def lf30(c):                #if ends in prep, its bad
    return -1 if c[0].get_attrib_tokens('pos_tags')[-1] == 'IN' else 0

def lf29b(c):                  #if pheno ends in VBG, its bad
    return -1 if c[1].get_attrib_tokens('pos_tags')[-1] == 'VBG' else 0

def lf30b(c):                #if ends in prep, its bad
    return -1 if c[1].get_attrib_tokens('pos_tags')[-1] == 'IN' else 0

def lf30c(c):                  #if pheno ends in VBG, its bad
    return -1 if c[1].get_attrib_tokens('pos_tags')[-1] in ['JJ', 'JJR', 'JJS'] else 0



def lf31(c):
    return 1 if len(get_between_tokens(c, attrib='words')) <= 2 else 0

def lf32(c):
     return 1 if any([word in get_left_tokens(c, window=4, attrib='words') for word in ['is', 'are']]) else 0
        
def lf33(c):
    return 1 if any([word in get_left_tokens(c, window=4, attrib='words') for word in ['results', 'affected']]) else 0

def lf34(c):
    return -1 if len(get_between_tokens(c, attrib='words')) >= 5 else 0

def lf35(c):
    return 1 if any([word in get_left_tokens(c, window=4, attrib='words') for word in ['showed', 'were',]]) else 0
# Out:
# /home/CS341_Arabidopsis/venv/local/lib/python2.7/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
from snorkel.models.context import TemporaryContext
import re

print docs[15]
sent = docs[15].get_parent()
print sent
text = sent._asdict()['text']
splt = text.split()
print splt
print splt[4:5]
print "\n"
print "REGEX VERSION: "

resplit = re.split(' ',text)
print resplit
print resplit[4:5]
print "\n"

print docs[15].get_contexts()
print (docs[15][0]).get_attrib_tokens('words')
print len((docs[15][0]).get_attrib_tokens('words'))
# print (docs[15][0]).get_attrib_tokens('dep_parents')

#print LF_DP(docs[0])
print get_text_splits(docs[15])
# Out:
# Phenotypes(Span("constitutive overexpression of", sentence=421233, chars=[96,125], words=[18,20]), Span("strongly delayed flowering", sentence=421233, chars=[135,160], words=[23,25]))
# Sentence(Document PMC3043248,131,The interaction of nitrate with these pathways was investigated in 35S::FLC mutants, which have constitutive overexpression of FLC and strongly delayed flowering. )
# [u'The', u'interaction', u'of', u'nitrate', u'with', u'these', u'pathways', u'was', u'investigated', u'in', u'35S::FLC', u'mutants,', u'which', u'have', u'constitutive', u'overexpression', u'of', u'FLC', u'and', u'strongly', u'delayed', u'flowering.']
# [u'with']
#
#
# REGEX VERSION:
# [u'The', u'interaction', u'of', u'nitrate', u'with', u'these', u'pathways', u'was', u'investigated', u'in', u'35S::FLC', u'mutants,', u'which', u'have', u'constitutive', u'overexpression', u'of', u'FLC', u'and', u'strongly', u'delayed', u'flowering.', u'']
# [u'with']
#
#
# (Span("constitutive overexpression of", sentence=421233, chars=[96,125], words=[18,20]), Span("strongly delayed flowering", sentence=421233, chars=[135,160], words=[23,25]))
# [u'constitutive', u'overexpression', u'of']
# 3
# [u'The interaction of nitrate with these pathways was investigated in 35S::FLC mutants, which have ', '{{A}}', u' FLC and ', '{{B}}', u'. ']

# %% [markdown]
# # Running LFs on the Training Set

# %%
LFs = [
    LF_mutant,
    LF_variant,
    LF_express,
    LF_JJ,
    LF_IN,
    LF_dna,
    LF_rna,
    LF_snp,
    LF_protein,
    LF_LRB,
    LF_RRB,
    LF_NNP,
    lfdistBtw0,
    lfdistBtw,
    lfdistBtwNeg,
    lfdistBtwNeg2,
    lf1,
    lf2,
    lf3,
    lf4,
    lf5,
    lf6,
    lf7,
    lf8,
    lf9,
    lf10,
    lf11,
    lf2a,
    lf12,
    lf13,
    lf14,
    lf15,
    lf16,
    lf17,
    lf18,
    lf20,
    lf21,
    lf22,
    lf23,
    lf24,
    lf25,
    lf26,
    lf27,
    lf29,
    lf30,
#     lf29b,
#     lf30b,
#     lf30c,
    lf31,
    lf32,
    lf33,
    lf34,
    lf35,
    LF_phenotype_dp,
    LF_mutation,
    LF_pheno,
    LF_dev_dp,
    LF_protein_dp,
    LF_network_dp,
    LF_JJ_dp,
    lf_helpers,
    lf_adjwords,
    lf_statswords,
    lf_proteinIn,
    lfnegWords,
    resultsAlone,
    lfLenCand,
]

# %%
from snorkel.annotations import LabelAnnotator
import multiprocessing
labeler = LabelAnnotator(f=LFs)

# %%
# %time L_train = labeler.apply(split=0, parallelism=multiprocessing.cpu_count())
L_train
# Out:
# Clearing existing...
# Running UDF...
# CPU times: user 2min 17s, sys: 9.16 s, total: 2min 27s
# Wall time: 7min 52s
# <39176x64 sparse matrix of type '<type 'numpy.float64'>'
# 	with 236281 stored elements in Compressed Sparse Row format>

# %%
L_train.lf_stats(session)
# Out:
#                   j  Coverage  Overlaps  Conflicts
# LF_mutant         0  0.024530  0.024530   0.022744
# LF_variant        1  0.000077  0.000077   0.000077
# LF_express        2  0.004978  0.004952   0.004850
# LF_JJ             3  0.000000  0.000000   0.000000
# LF_IN             4  0.000000  0.000000   0.000000
# LF_dna            5  0.004926  0.004926   0.003931
# LF_rna            6  0.001889  0.001889   0.001480
# LF_snp            7  0.000332  0.000332   0.000230
# LF_protein        8  0.020191  0.020191   0.015545
# LF_LRB            9  0.000000  0.000000   0.000000
# LF_RRB           10  0.000000  0.000000   0.000000
# LF_NNP           11  0.108281  0.108102   0.080993
# lfdistBtw0       12  0.318052  0.318052   0.300133
# lfdistBtw        13  0.411298  0.411298   0.389779
# lfdistBtwNeg     14  0.505948  0.505948   0.280376
# lfdistBtwNeg2    15  0.371401  0.371401   0.221105
# lf1              16  0.159588  0.159536   0.159511
# lf2              17  0.049571  0.049546   0.049469
# lf3              18  0.035277  0.035226   0.032699
# lf4              19  0.001634  0.001634   0.001608
# lf5              20  0.065448  0.065372   0.061032
# lf6              21  0.001940  0.001940   0.001940
# lf7              22  0.025143  0.025143   0.019170
# lf8              23  0.011921  0.011895   0.008857
# lf9              24  0.029406  0.029355   0.023816
# lf10             25  0.011997  0.011997   0.010210
# lf11             26  0.227793  0.227512   0.156244
# lf2a             27  0.015418  0.015367   0.014984
# lf12             28  0.078441  0.078441   0.078441
# lf13             29  0.000000  0.000000   0.000000
# ...              ..       ...       ...        ...
# lf18             34  0.075990  0.075914   0.073897
# lf20             35  0.427634  0.425771   0.304166
# lf21             36  0.075250  0.075250   0.075250
# lf22             37  0.007632  0.007632   0.005794
# lf23             38  0.000000  0.000000   0.000000
# lf24             39  0.797044  0.793394   0.564734
# lf25             40  0.000740  0.000740   0.000587
# lf26             41  0.006815  0.006815   0.006815
# lf27             42  0.000434  0.000434   0.000332
# lf29             43  0.014831  0.014831   0.010823
# lf30             44  0.187972  0.187487   0.140418
# lf31             45  0.411298  0.411298   0.389779
# lf32             46  0.044032  0.044032   0.043675
# lf33             47  0.007913  0.007913   0.007887
# lf34             48  0.505948  0.505948   0.280376
# lf35             49  0.010159  0.010134   0.010006
# LF_phenotype_dp  50  0.000077  0.000077   0.000077
# LF_mutation      51  0.016873  0.016847   0.016260
# LF_pheno         52  0.012788  0.012788   0.012380
# LF_dev_dp        53  0.000791  0.000791   0.000613
# LF_protein_dp    54  0.007326  0.007326   0.004952
# LF_network_dp    55  0.000408  0.000408   0.000383
# LF_JJ_dp         56  0.000000  0.000000   0.000000
# lf_helpers       57  0.049546  0.049546   0.049086
# lf_adjwords      58  0.120763  0.120227   0.113692
# lf_statswords    59  0.013605  0.013529   0.010057
# lf_proteinIn     60  0.074433  0.074382   0.051409
# lfnegWords       61  0.011129  0.011078   0.007581
# resultsAlone     62  0.009317  0.009317   0.006943
# lfLenCand        63  0.387023  0.386818   0.253497
#
# [64 rows x 4 columns]

# %% [markdown]
# * <b>Coverage</b> is the fraction of candidates that the labeling function emits a non-zero label for.
# * <b>Overlap</b> is the fraction candidates that the labeling function emits a non-zero label for and that another labeling function emits a non-zero label for.
# * <b>Conflict</b> is the fraction candidates that the labeling function emits a non-zero label for and that another labeling function emits a conflicting non-zero label for.

# %% [markdown]
# # Generative Model

# %%
from snorkel.learning.structure import DependencySelector
ds = DependencySelector()
deps = ds.select(L_train, threshold=0.1)
len(deps)
# Out:
# 35

# %%
deps # (lf, lf, relationship_type)
# Out:
# {(0, 20, 0),
#  (0, 34, 0),
#  (8, 31, 0),
#  (8, 60, 0),
#  (12, 13, 0),
#  (12, 45, 0),
#  (13, 39, 0),
#  (13, 45, 0),
#  (14, 15, 0),
#  (14, 48, 0),
#  (15, 22, 0),
#  (15, 48, 0),
#  (16, 17, 0),
#  (16, 28, 0),
#  (16, 36, 0),
#  (18, 41, 0),
#  (18, 58, 0),
#  (20, 30, 0),
#  (20, 34, 0),
#  (22, 23, 0),
#  (24, 32, 0),
#  (26, 35, 0),
#  (26, 63, 0),
#  (28, 36, 0),
#  (30, 52, 0),
#  (31, 60, 0),
#  (34, 51, 0),
#  (35, 44, 0),
#  (39, 45, 0),
#  (39, 63, 0),
#  (46, 57, 0),
#  (47, 57, 0),
#  (51, 58, 0),
#  (54, 60, 0),
#  (62, 63, 0)}

# %%
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel(lf_propensity=True)
gen_model.train(
    L_train, deps=deps, epochs=2, decay=0.95, step_size=0.1/L_train.shape[0],
    init_acc=2.0, reg_param=0.0,
    verbose=True
)
# Out:
# FACTOR 0: STARTED BURN-IN...
# FACTOR 0: DONE WITH BURN-IN
# FACTOR 0: STARTED LEARNING
# FACTOR 0: EPOCH #0
# Current stepsize = 2.55258321421e-06
# Learning epoch took 0.000 sec.
# Weights:
#     weightId: 0
#         isFixed: False
#         weight:  2.0
#
#     weightId: 1
#         isFixed: False
#         weight:  2.0
#
#     weightId: 2
#         isFixed: False
#         weight:  2.0
#
#     weightId: 3
#         isFixed: False
#         weight:  2.0
#
#     weightId: 4
#         isFixed: False
#         weight:  2.0
#
#     weightId: 5
#         isFixed: False
#         weight:  2.0
#
#     weightId: 6
#         isFixed: False
#         weight:  2.0
#
#     weightId: 7
#         isFixed: False
#         weight:  2.0
#
#     weightId: 8
#         isFixed: False
#         weight:  2.0
#
#     weightId: 9
#         isFixed: False
#         weight:  2.0
#
#     weightId: 10
#         isFixed: False
#         weight:  2.0
#
#     weightId: 11
#         isFixed: False
#         weight:  2.0
#
#     weightId: 12
#         isFixed: False
#         weight:  2.0
#
#     weightId: 13
#         isFixed: False
#         weight:  2.0
#
#     weightId: 14
#         isFixed: False
#         weight:  2.0
#
#     weightId: 15
#         isFixed: False
#         weight:  2.0
#
#     weightId: 16
#         isFixed: False
#         weight:  2.0
#
#     weightId: 17
#         isFixed: False
#         weight:  2.0
#
#     weightId: 18
#         isFixed: False
#         weight:  2.0
#
#     weightId: 19
#         isFixed: False
#         weight:  2.0
#
#     weightId: 20
#         isFixed: False
#         weight:  2.0
#
#     weightId: 21
#         isFixed: False
#         weight:  2.0
#
#     weightId: 22
#         isFixed: False
#         weight:  2.0
#
#     weightId: 23
#         isFixed: False
#         weight:  2.0
#
#     weightId: 24
#         isFixed: False
#         weight:  2.0
#
#     weightId: 25
#         isFixed: False
#         weight:  2.0
#
#     weightId: 26
#         isFixed: False
#         weight:  2.0
#
#     weightId: 27
#         isFixed: False
#         weight:  2.0
#
#     weightId: 28
#         isFixed: False
#         weight:  2.0
#
#     weightId: 29
#         isFixed: False
#         weight:  2.0
#
#     weightId: 30
#         isFixed: False
#         weight:  2.0
#
#     weightId: 31
#         isFixed: False
#         weight:  2.0
#
#     weightId: 32
#         isFixed: False
#         weight:  2.0
#
#     weightId: 33
#         isFixed: False
#         weight:  2.0
#
#     weightId: 34
#         isFixed: False
#         weight:  2.0
#
#     weightId: 35
#         isFixed: False
#         weight:  2.0
#
#     weightId: 36
#         isFixed: False
#         weight:  2.0
#
#     weightId: 37
#         isFixed: False
#         weight:  2.0
#
#     weightId: 38
#         isFixed: False
#         weight:  2.0
#
#     weightId: 39
#         isFixed: False
#         weight:  2.0
#
#     weightId: 40
#         isFixed: False
#         weight:  2.0
#
#     weightId: 41
#         isFixed: False
#         weight:  2.0
#
#     weightId: 42
#         isFixed: False
#         weight:  2.0
#
#     weightId: 43
#         isFixed: False
#         weight:  2.0
#
#     weightId: 44
#         isFixed: False
#         weight:  2.0
#
#     weightId: 45
#         isFixed: False
#         weight:  2.0
#
#     weightId: 46
#         isFixed: False
#         weight:  2.0
#
#     weightId: 47
#         isFixed: False
#         weight:  2.0
#
#     weightId: 48
#         isFixed: False
#         weight:  2.0
#
#     weightId: 49
#         isFixed: False
#         weight:  2.0
#
#     weightId: 50
#         isFixed: False
#         weight:  2.0
#
#     weightId: 51
#         isFixed: False
#         weight:  2.0
#
#     weightId: 52
#         isFixed: False
#         weight:  2.0
#
#     weightId: 53
#         isFixed: False
#         weight:  2.0
#
#     weightId: 54
#         isFixed: False
#         weight:  2.0
#
#     weightId: 55
#         isFixed: False
#         weight:  2.0
#
#     weightId: 56
#         isFixed: False
#         weight:  2.0
#
#     weightId: 57
#         isFixed: False
#         weight:  2.0
#
#     weightId: 58
#         isFixed: False
#         weight:  2.0
#
#     weightId: 59
#         isFixed: False
#         weight:  2.0
#
#     weightId: 60
#         isFixed: False
#         weight:  2.0
#
#     weightId: 61
#         isFixed: False
#         weight:  2.0
#
#     weightId: 62
#         isFixed: False
#         weight:  2.0
#
#     weightId: 63
#         isFixed: False
#         weight:  2.0
#
#     weightId: 64
#         isFixed: False
#         weight:  1.0
#
#     weightId: 65
#         isFixed: False
#         weight:  1.0
#
#     weightId: 66
#         isFixed: False
#         weight:  1.0
#
#     weightId: 67
#         isFixed: False
#         weight:  1.0
#
#     weightId: 68
#         isFixed: False
#         weight:  1.0
#
#     weightId: 69
#         isFixed: False
#         weight:  1.0
#
#     weightId: 70
#         isFixed: False
#         weight:  1.0
#
#     weightId: 71
#         isFixed: False
#         weight:  1.0
#
#     weightId: 72
#         isFixed: False
#         weight:  1.0
#
#     weightId: 73
#         isFixed: False
#         weight:  1.0
#
#     weightId: 74
#         isFixed: False
#         weight:  1.0
#
#     weightId: 75
#         isFixed: False
#         weight:  1.0
#
#     weightId: 76
#         isFixed: False
#         weight:  1.0
#
#     weightId: 77
#         isFixed: False
#         weight:  1.0
#
#     weightId: 78
#         isFixed: False
#         weight:  1.0
#
#     weightId: 79
#         isFixed: False
#         weight:  1.0
#
#     weightId: 80
#         isFixed: False
#         weight:  1.0
#
#     weightId: 81
#         isFixed: False
#         weight:  1.0
#
#     weightId: 82
#         isFixed: False
#         weight:  1.0
#
#     weightId: 83
#         isFixed: False
#         weight:  1.0
#
#     weightId: 84
#         isFixed: False
#         weight:  1.0
#
#     weightId: 85
#         isFixed: False
#         weight:  1.0
#
#     weightId: 86
#         isFixed: False
#         weight:  1.0
#
#     weightId: 87
#         isFixed: False
#         weight:  1.0
#
#     weightId: 88
#         isFixed: False
#         weight:  1.0
#
#     weightId: 89
#         isFixed: False
#         weight:  1.0
#
#     weightId: 90
#         isFixed: False
#         weight:  1.0
#
#     weightId: 91
#         isFixed: False
#         weight:  1.0
#
#     weightId: 92
#         isFixed: False
#         weight:  1.0
#
#     weightId: 93
#         isFixed: False
#         weight:  1.0
#
#     weightId: 94
#         isFixed: False
#         weight:  1.0
#
#     weightId: 95
#         isFixed: False
#         weight:  1.0
#
#     weightId: 96
#         isFixed: False
#         weight:  1.0
#
#     weightId: 97
#         isFixed: False
#         weight:  1.0
#
#     weightId: 98
#         isFixed: False
#         weight:  1.0
#
#     weightId: 99
#         isFixed: False
#         weight:  1.0
#
#     weightId: 100
#         isFixed: False
#         weight:  1.0
#
#     weightId: 101
#         isFixed: False
#         weight:  1.0
#
#     weightId: 102
#         isFixed: False
#         weight:  1.0
#
#     weightId: 103
#         isFixed: False
#         weight:  1.0
#
#     weightId: 104
#         isFixed: False
#         weight:  1.0
#
#     weightId: 105
#         isFixed: False
#         weight:  1.0
#
#     weightId: 106
#         isFixed: False
#         weight:  1.0
#
#     weightId: 107
#         isFixed: False
#         weight:  1.0
#
#     weightId: 108
#         isFixed: False
#         weight:  1.0
#
#     weightId: 109
#         isFixed: False
#         weight:  1.0
#
#     weightId: 110
#         isFixed: False
#         weight:  1.0
#
#     weightId: 111
#         isFixed: False
#         weight:  1.0
#
#     weightId: 112
#         isFixed: False
#         weight:  1.0
#
#     weightId: 113
#         isFixed: False
#         weight:  1.0
#
#     weightId: 114
#         isFixed: False
#         weight:  1.0
#
#     weightId: 115
#         isFixed: False
#         weight:  1.0
#
#     weightId: 116
#         isFixed: False
#         weight:  1.0
#
#     weightId: 117
#         isFixed: False
#         weight:  1.0
#
#     weightId: 118
#         isFixed: False
#         weight:  1.0
#
#     weightId: 119
#         isFixed: False
#         weight:  1.0
#
#     weightId: 120
#         isFixed: False
#         weight:  1.0
#
#     weightId: 121
#         isFixed: False
#         weight:  1.0
#
#     weightId: 122
#         isFixed: False
#         weight:  1.0
#
#     weightId: 123
#         isFixed: False
#         weight:  1.0
#
#     weightId: 124
#         isFixed: False
#         weight:  1.0
#
#     weightId: 125
#         isFixed: False
#         weight:  1.0
#
#     weightId: 126
#         isFixed: False
#         weight:  1.0
#
#     weightId: 127
#         isFixed: False
#         weight:  1.0
#
#     weightId: 128
#         isFixed: False
#         weight:  1.0
#
#     weightId: 129
#         isFixed: False
#         weight:  1.0
#
#     weightId: 130
#         isFixed: False
#         weight:  1.0
#
#     weightId: 131
#         isFixed: False
#         weight:  1.0
#
#     weightId: 132
#         isFixed: False
#         weight:  1.0
#
#     weightId: 133
#         isFixed: False
#         weight:  1.0
#
#     weightId: 134
#         isFixed: False
#         weight:  1.0
#
#     weightId: 135
#         isFixed: False
#         weight:  1.0
#
#     weightId: 136
#         isFixed: False
#         weight:  1.0
#
#     weightId: 137
#         isFixed: False
#         weight:  1.0
#
#     weightId: 138
#         isFixed: False
#         weight:  1.0
#
#     weightId: 139
#         isFixed: False
#         weight:  1.0
#
#     weightId: 140
#         isFixed: False
#         weight:  1.0
#
#     weightId: 141
#         isFixed: False
#         weight:  1.0
#
#     weightId: 142
#         isFixed: False
#         weight:  1.0
#
#     weightId: 143
#         isFixed: False
#         weight:  1.0
#
#     weightId: 144
#         isFixed: False
#         weight:  1.0
#
#     weightId: 145
#         isFixed: False
#         weight:  1.0
#
#     weightId: 146
#         isFixed: False
#         weight:  1.0
#
#     weightId: 147
#         isFixed: False
#         weight:  1.0
#
#     weightId: 148
#         isFixed: False
#         weight:  1.0
#
#     weightId: 149
#         isFixed: False
#         weight:  1.0
#
#     weightId: 150
#         isFixed: False
#         weight:  1.0
#
#     weightId: 151
#         isFixed: False
#         weight:  1.0
#
#     weightId: 152
#         isFixed: False
#         weight:  1.0
#
#     weightId: 153
#         isFixed: False
#         weight:  1.0
#
#     weightId: 154
#         isFixed: False
#         weight:  1.0
#
#     weightId: 155
#         isFixed: False
#         weight:  1.0
#
#     weightId: 156
#         isFixed: False
#         weight:  1.0
#
#     weightId: 157
#         isFixed: False
#         weight:  1.0
#
#     weightId: 158
#         isFixed: False
#         weight:  1.0
#
#     weightId: 159
#         isFixed: False
#         weight:  1.0
#
#     weightId: 160
#         isFixed: False
#         weight:  1.0
#
#     weightId: 161
#         isFixed: False
#         weight:  1.0
#
#     weightId: 162
#         isFixed: False
#         weight:  1.0
# FACTOR 0: EPOCH #1
# Current stepsize = 2.4249540535e-06
# Learning epoch took 8.805 sec.
# Weights:
#     weightId: 0
#         isFixed: False
#         weight:  1.80412752706
#
#     weightId: 1
#         isFixed: False
#         weight:  1.81806973658
#
#     weightId: 2
#         isFixed: False
#         weight:  1.817883398
#
#     weightId: 3
#         isFixed: False
#         weight:  1.81766387585
#
#     weightId: 4
#         isFixed: False
#         weight:  1.81791658159
#
#     weightId: 5
#         isFixed: False
#         weight:  1.81890443129
#
#     weightId: 6
#         isFixed: False
#         weight:  1.81871298755
#
#     weightId: 7
#         isFixed: False
#         weight:  1.8179906065
#
#     weightId: 8
#         isFixed: False
#         weight:  1.80628701246
#
#     weightId: 9
#         isFixed: False
#         weight:  1.81820757607
#
#     weightId: 10
#         isFixed: False
#         weight:  1.81805442108
#
#     weightId: 11
#         isFixed: False
#         weight:  1.83054676333
#
#     weightId: 12
#         isFixed: False
#         weight:  1.83031703084
#
#     weightId: 13
#         isFixed: False
#         weight:  1.82814988769
#
#     weightId: 14
#         isFixed: False
#         weight:  1.89818511334
#
#     weightId: 15
#         isFixed: False
#         weight:  1.87149275067
#
#     weightId: 16
#         isFixed: False
#         weight:  1.77494894834
#
#     weightId: 17
#         isFixed: False
#         weight:  1.79891004697
#
#     weightId: 18
#         isFixed: False
#         weight:  1.80317796611
#
#     weightId: 19
#         isFixed: False
#         weight:  1.81781192567
#
#     weightId: 20
#         isFixed: False
#         weight:  1.80193485808
#
#     weightId: 21
#         isFixed: False
#         weight:  1.81768429651
#
#     weightId: 22
#         isFixed: False
#         weight:  1.80805084746
#
#     weightId: 23
#         isFixed: False
#         weight:  1.80883449051
#
#     weightId: 24
#         isFixed: False
#         weight:  1.81129773331
#
#     weightId: 25
#         isFixed: False
#         weight:  1.81884316929
#
#     weightId: 26
#         isFixed: False
#         weight:  1.83436032265
#
#     weightId: 27
#         isFixed: False
#         weight:  1.81778639984
#
#     weightId: 28
#         isFixed: False
#         weight:  1.79183173372
#
#     weightId: 29
#         isFixed: False
#         weight:  1.81847814989
#
#     weightId: 30
#         isFixed: False
#         weight:  1.80308607311
#
#     weightId: 31
#         isFixed: False
#         weight:  1.81020778028
#
#     weightId: 32
#         isFixed: False
#         weight:  1.81079997959
#
#     weightId: 33
#         isFixed: False
#         weight:  1.84158158056
#
#     weightId: 34
#         isFixed: False
#         weight:  1.7975520727
#
#     weightId: 35
#         isFixed: False
#         weight:  1.85105676945
#
#     weightId: 36
#         isFixed: False
#         weight:  1.79243159078
#
#     weightId: 37
#         isFixed: False
#         weight:  1.81904482337
#
#     weightId: 38
#         isFixed: False
#         weight:  1.81787318767
#
#     weightId: 39
#         isFixed: False
#         weight:  1.88002858893
#
#     weightId: 40
#         isFixed: False
#         weight:  1.81815652441
#
#     weightId: 41
#         isFixed: False
#         weight:  1.80734888708
#
#     weightId: 42
#         isFixed: False
#         weight:  1.81856749031
#
#     weightId: 43
#         isFixed: False
#         weight:  1.81982591383
#
#     weightId: 44
#         isFixed: False
#         weight:  1.82652899735
#
#     weightId: 45
#         isFixed: False
#         weight:  1.82809883603
#
#     weightId: 46
#         isFixed: False
#         weight:  1.80707831326
#
#     weightId: 47
#         isFixed: False
#         weight:  1.80697876251
#
#     weightId: 48
#         isFixed: False
#         weight:  1.89808301001
#
#     weightId: 49
#         isFixed: False
#         weight:  1.817914029
#
#     weightId: 50
#         isFixed: False
#         weight:  1.81798550133
#
#     weightId: 51
#         isFixed: False
#         weight:  1.80248366347
#
#     weightId: 52
#         isFixed: False
#         weight:  1.80749183174
#
#     weightId: 53
#         isFixed: False
#         weight:  1.81810036758
#
#     weightId: 54
#         isFixed: False
#         weight:  1.80842097203
#
#     weightId: 55
#         isFixed: False
#         weight:  1.81801613233
#
#     weightId: 56
#         isFixed: False
#         weight:  1.81811313049
#
#     weightId: 57
#         isFixed: False
#         weight:  1.80301460078
#
#     weightId: 58
#         isFixed: False
#         weight:  1.8019016745
#
#     weightId: 59
#         isFixed: False
#         weight:  1.81982846641
#
#     weightId: 60
#         isFixed: False
#         weight:  1.81353634879
#
#     weightId: 61
#         isFixed: False
#         weight:  1.81911884828
#
#     weightId: 62
#         isFixed: False
#         weight:  1.80878088626
#
#     weightId: 63
#         isFixed: False
#         weight:  1.8525704513
#
#     weightId: 64
#         isFixed: False
#         weight:  0.903348989176
#
#     weightId: 65
#         isFixed: False
#         weight:  0.905511027158
#
#     weightId: 66
#         isFixed: False
#         weight:  0.9060521748
#
#     weightId: 67
#         isFixed: False
#         weight:  0.905567183989
#
#     weightId: 68
#         isFixed: False
#         weight:  0.905429344495
#
#     weightId: 69
#         isFixed: False
#         weight:  0.906121094547
#
#     weightId: 70
#         isFixed: False
#         weight:  0.905794363895
#
#     weightId: 71
#         isFixed: False
#         weight:  0.905485501326
#
#     weightId: 72
#         isFixed: False
#         weight:  0.902858893199
#
#     weightId: 73
#         isFixed: False
#         weight:  0.905562078823
#
#     weightId: 74
#         isFixed: False
#         weight:  0.905482948743
#
#     weightId: 75
#         isFixed: False
#         weight:  0.91619358791
#
#     weightId: 76
#         isFixed: False
#         weight:  0.932586277312
#
#     weightId: 77
#         isFixed: False
#         weight:  0.941497345313
#
#     weightId: 78
#         isFixed: False
#         weight:  0.951332448437
#
#     weightId: 79
#         isFixed: False
#         weight:  0.937459158668
#
#     weightId: 80
#         isFixed: False
#         weight:  0.916321217071
#
#     weightId: 81
#         isFixed: False
#         weight:  0.907190626913
#
#     weightId: 82
#         isFixed: False
#         weight:  0.904464468041
#
#     weightId: 83
#         isFixed: False
#         weight:  0.90562334082
#
#     weightId: 84
#         isFixed: False
#         weight:  0.906899632427
#
#     weightId: 85
#         isFixed: False
#         weight:  0.905730549315
#
#     weightId: 86
#         isFixed: False
#         weight:  0.903558300999
#
#     weightId: 87
#         isFixed: False
#         weight:  0.903430671839
#
#     weightId: 88
#         isFixed: False
#         weight:  0.905360424749
#
#     weightId: 89
#         isFixed: False
#         weight:  0.906812844598
#
#     weightId: 90
#         isFixed: False
#         weight:  0.923652236062
#
#     weightId: 91
#         isFixed: False
#         weight:  0.907042577087
#
#     weightId: 92
#         isFixed: False
#         weight:  0.90868899326
#
#     weightId: 93
#         isFixed: False
#         weight:  0.905633551153
#
#     weightId: 94
#         isFixed: False
#         weight:  0.903177966101
#
#     weightId: 95
#         isFixed: False
#         weight:  0.905362977332
#
#     weightId: 96
#         isFixed: False
#         weight:  0.904576781702
#
#     weightId: 97
#         isFixed: False
#         weight:  0.923496528486
#
#     weightId: 98
#         isFixed: False
#         weight:  0.907943638962
#
#     weightId: 99
#         isFixed: False
#         weight:  0.943771696957
#
#     weightId: 100
#         isFixed: False
#         weight:  0.908454155604
#
#     weightId: 101
#         isFixed: False
#         weight:  0.906210434959
#
#     weightId: 102
#         isFixed: False
#         weight:  0.905217480089
#
#     weightId: 103
#         isFixed: False
#         weight:  0.980038799265
#
#     weightId: 104
#         isFixed: False
#         weight:  0.90548039616
#
#     weightId: 105
#         isFixed: False
#         weight:  0.903063099856
#
#     weightId: 106
#         isFixed: False
#         weight:  0.905618235653
#
#     weightId: 107
#         isFixed: False
#         weight:  0.90710894425
#
#     weightId: 108
#         isFixed: False
#         weight:  0.921076679599
#
#     weightId: 109
#         isFixed: False
#         weight:  0.941446293648
#
#     weightId: 110
#         isFixed: False
#         weight:  0.906667347354
#
#     weightId: 111
#         isFixed: False
#         weight:  0.903093730854
#
#     weightId: 112
#         isFixed: False
#         weight:  0.951337553604
#
#     weightId: 113
#         isFixed: False
#         weight:  0.906526955278
#
#     weightId: 114
#         isFixed: False
#         weight:  0.905590157238
#
#     weightId: 115
#         isFixed: False
#         weight:  0.902555135796
#
#     weightId: 116
#         isFixed: False
#         weight:  0.903382172758
#
#     weightId: 117
#         isFixed: False
#         weight:  0.905638656319
#
#     weightId: 118
#         isFixed: False
#         weight:  0.902848682866
#
#     weightId: 119
#         isFixed: False
#         weight:  0.905669287318
#
#     weightId: 120
#         isFixed: False
#         weight:  0.905498264242
#
#     weightId: 121
#         isFixed: False
#         weight:  0.906041964467
#
#     weightId: 122
#         isFixed: False
#         weight:  0.913007964059
#
#     weightId: 123
#         isFixed: False
#         weight:  0.906807739431
#
#     weightId: 124
#         isFixed: False
#         weight:  0.907826220134
#
#     weightId: 125
#         isFixed: False
#         weight:  0.906743924851
#
#     weightId: 126
#         isFixed: False
#         weight:  0.90326475393
#
#     weightId: 127
#         isFixed: False
#         weight:  0.939080049009
#
#     weightId: 128
#         isFixed: False
#         weight:  0.994968858485
#
#     weightId: 129
#         isFixed: False
#         weight:  0.986946089442
#
#     weightId: 130
#         isFixed: False
#         weight:  0.999395037778
#
#     weightId: 131
#         isFixed: False
#         weight:  0.989667143149
#
#     weightId: 132
#         isFixed: False
#         weight:  0.984319481315
#
#     weightId: 133
#         isFixed: False
#         weight:  0.984250561568
#
#     weightId: 134
#         isFixed: False
#         weight:  0.822756279353
#
#     weightId: 135
#         isFixed: False
#         weight:  1.00170512559
#
#     weightId: 136
#         isFixed: False
#         weight:  0.975906167041
#
#     weightId: 137
#         isFixed: False
#         weight:  1.00390034715
#
#     weightId: 138
#         isFixed: False
#         weight:  0.932379518071
#
#     weightId: 139
#         isFixed: False
#         weight:  0.975898509291
#
#     weightId: 140
#         isFixed: False
#         weight:  0.971311517255
#
#     weightId: 141
#         isFixed: False
#         weight:  0.986808249949
#
#     weightId: 142
#         isFixed: False
#         weight:  0.986261997141
#
#     weightId: 143
#         isFixed: False
#         weight:  1.00068919747
#
#     weightId: 144
#         isFixed: False
#         weight:  0.982428017153
#
#     weightId: 145
#         isFixed: False
#         weight:  0.987742495405
#
#     weightId: 146
#         isFixed: False
#         weight:  0.978387277925
#
#     weightId: 147
#         isFixed: False
#         weight:  1.00251684705
#
#     weightId: 148
#         isFixed: False
#         weight:  1.00907443333
#
#     weightId: 149
#         isFixed: False
#         weight:  0.920175617724
#
#     weightId: 150
#         isFixed: False
#         weight:  0.930431897079
#
#     weightId: 151
#         isFixed: False
#         weight:  1.00365529916
#
#     weightId: 152
#         isFixed: False
#         weight:  1.00568460282
#
#     weightId: 153
#         isFixed: False
#         weight:  0.991464161732
#
#     weightId: 154
#         isFixed: False
#         weight:  0.986639779457
#
#     weightId: 155
#         isFixed: False
#         weight:  0.924361854196
#
#     weightId: 156
#         isFixed: False
#         weight:  0.822735858687
#
#     weightId: 157
#         isFixed: False
#         weight:  0.906820502347
#
#     weightId: 158
#         isFixed: False
#         weight:  1.00403818664
#
#     weightId: 159
#         isFixed: False
#         weight:  0.998016642843
#
#     weightId: 160
#         isFixed: False
#         weight:  0.979354706963
#
#     weightId: 161
#         isFixed: False
#         weight:  0.993279048397
#
#     weightId: 162
#         isFixed: False
#         weight:  0.931720951602
# FACTOR 0: DONE WITH LEARNING

# %% [markdown]
# We now apply the generative model to the training candidates to get the noise-aware training label set. We'll refer to these as the training marginals:

# %%
train_marginals = gen_model.marginals(L_train)

# %%
import matplotlib.pyplot as plt
plt.hist(train_marginals, bins=20)
plt.show()

# %%
gen_model.weights.lf_accuracy()
# Out:
# array([ 0.83466309,  0.83884825,  0.8388506 ,  0.83890713,  0.83888491,
#         0.83912513,  0.83904394,  0.83884476,  0.83523438,  0.83892555,
#         0.83891239,  0.84215823,  0.84140451,  0.84071187,  0.85848555,
#         0.85199319,  0.82647073,  0.83345499,  0.83439367,  0.83885011,
#         0.83394564,  0.83879515,  0.8357378 ,  0.83608942,  0.83676187,
#         0.83912831,  0.84268154,  0.83881322,  0.83120999,  0.8389336 ,
#         0.8343679 ,  0.83630841,  0.83667299,  0.84499183,  0.83276381,
#         0.84707324,  0.83140056,  0.83913884,  0.83881578,  0.85430274,
#         0.83891668,  0.83577892,  0.83898957,  0.83939795,  0.84089967,
#         0.8407229 ,  0.8355706 ,  0.83556359,  0.85846755,  0.8388272 ,
#         0.8388621 ,  0.83420952,  0.83571898,  0.83892122,  0.83600848,
#         0.83889607,  0.83887968,  0.83435936,  0.83402028,  0.8393486 ,
#         0.83710577,  0.83912723,  0.83616647,  0.84741476])

# %%
from snorkel.annotations import save_marginals
save_marginals(session, L_train, train_marginals)
# Out:
# Saved 39176 training marginals

# %%
from snorkel.annotations import load_marginals
train_marginals = load_marginals(session, split=0)

# %% [markdown]
# ### Using the Model to Iterate on Labeling Functions
# Now that we have learned the generative model, we can stop here and use this to potentially debug and/or improve our labeling function set. First, we apply the LFs to our development set:

# %%
L_dev = labeler.apply_existing(split=1, parallelism=multiprocessing.cpu_count())
# Out:
# Clearing existing...
# Running UDF...

# %%
from snorkel.annotations import load_gold_labels
L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)

# %%
tp, fp, tn, fn = gen_model.score(session, L_dev, L_gold_dev)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.508
# Neg. class accuracy: 0.681
# Precision            0.507
# Recall               0.508
# F1                   0.507
# ----------------------------------------
# TP: 412 | FP: 401 | TN: 857 | FN: 399
# ========================================

# %%
from snorkel.viewer import SentenceNgramViewer

# NOTE: This if-then statement is only to avoid opening the viewer during automated testing of this notebook
# You should ignore this!
import os
if 'CI' not in os.environ:
    sv = SentenceNgramViewer(fn, session, height=400)
else:
    sv = None

# %%
sv

# %% [markdown]
# At this point, we should be getting an F1 score of around 0.6 to 0.7 on the development set, which is pretty good! However, we should be very careful in interpreting this. Since we developed our labeling functions using this development set as a guide, and our generative model is composed of these labeling functions, we expect it to score very well here!
# In fact, it is probably somewhat overfit to this set. However this is fine, since in the next tutorial, we'll train a more powerful end extraction model which will generalize beyond the development set, and which we will evaluate on a blind test set (i.e. one we never looked at during development).

# %% [markdown]
# ## Doing Some Error Analysis

# %%
At this point, we might want to look at some examples in one of the error buckets. For example, one of the false negatives that we did not correctly label as true mentions. To do this, we can again just use the Viewer:

# %%
from snorkel.viewer import SentenceNgramViewer

# NOTE: This if-then statement is only to avoid opening the viewer during automated testing of this notebook
# You should ignore this!
import os
if 'CI' not in os.environ:
    sv = SentenceNgramViewer(fp, session, height=400)
else:
    sv = None

# %%
sv

# %%
from snorkel.lf_helpers import (
    get_left_tokens,
    get_between_tokens,
    get_right_tokens,
    contains_token,
    get_doc_candidate_spans,
    get_sent_candidate_spans,
    get_text_between,
    get_text_splits,
    get_tagged_text,
    is_inverted,
    get_tagged_text,
)
c = sv.get_selected() if sv else list(fp.union(fn))[0]
print(c)
print("\n")

c.labels
fp

# %% [markdown]
# ## Automatically Creating Features

# %%
from snorkel.annotations import FeatureAnnotator
import multiprocessing
featurizer = FeatureAnnotator()

# %%
# %time F_train = featurizer.apply(split=0, parallelism=multiprocessing.cpu_count())
F_train
# Out:
# Clearing existing...
# Running UDF...
# CPU times: user 13min 19s, sys: 48.7 s, total: 14min 8s
# Wall time: 57min 15s
# <39176x304293 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1794331 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Next, we apply the feature set we just got from the training set to the dev and test sets by using apply_existing:

# %%
# %%time
F_dev  = featurizer.apply_existing(split=1, parallelism=multiprocessing.cpu_count())
F_test = featurizer.apply_existing(split=2, parallelism=multiprocessing.cpu_count())
# Out:
# Clearing existing...
# Running UDF...
# Clearing existing...
# Running UDF...
# CPU times: user 2min 4s, sys: 5.41 s, total: 2min 9s
# Wall time: 5min 33s

# %%
F_train = featurizer.load_matrix(session, split=0)
F_dev   = featurizer.load_matrix(session, split=1)
F_test  = featurizer.load_matrix(session, split=2)

# %% [markdown]
# ## Training the Discriminative Model

# %% [markdown]
# We use the training marginals to train a discriminative model that classifies each Candidate as a true or false mention. We'll use a random hyperparameter search, evaluated on the development set labels, to find the best hyperparameters for our model. To run a hyperparameter search, we need labels for a development set. If they aren't already available, we can manually create labels using the Viewer.

# %%
from snorkel.learning import SparseLogisticRegression
disc_model = SparseLogisticRegression()

# %% [markdown]
# Now we set up and run the hyperparameter search, training our model with different hyperparamters and picking the best model configuration to keep. We'll set the random seed to maintain reproducibility.
# Note that we are fitting our model's parameters to the training set generated by our labeling functions, while we are picking hyperparamters with respect to score over the development set labels which we created by hand.

# %%
from snorkel.learning.utils import MentionScorer
from snorkel.learning import RandomSearch, ListParameter, RangeParameter

# Searching over learning rate
rate_param = RangeParameter('lr', 1e-6, 1e-2, step=1, log_base=10)
l1_param  = RangeParameter('l1_penalty', 1e-6, 1e-2, step=1, log_base=10)
l2_param  = RangeParameter('l2_penalty', 1e-6, 1e-2, step=1, log_base=10)

searcher = RandomSearch(session, disc_model, F_train, train_marginals, [rate_param, l1_param, l2_param], n=20)
# Out:
# Initialized RandomSearch search of size 20. Search space size = 125.

# %% [markdown]
# Next, we'll load in our dev set labels. We will pick the optimal result from the hyperparameter search by testing against these labels:

# %%
from snorkel.annotations import load_gold_labels
L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)

# %% [markdown]
# Finally, we run the hyperparameter search / train the end extraction model:

# %%
np.random.seed(1701)
searcher.fit(F_dev, L_gold_dev, n_epochs=50, rebalance=0.5, print_freq=25)
# Out:
# ============================================================
# [1] Testing lr = 1.00e-02, l1_penalty = 1.00e-03, l2_penalty = 1.00e-04
# ============================================================
# [SparseLR] lr=0.01 l1=0.001 l2=0.0001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.75s)	Avg. loss=0.914207	NNZ=304293
# [SparseLR] Epoch 25 (425.09s)	Avg. loss=0.575517	NNZ=304293
# [SparseLR] Epoch 49 (819.87s)	Avg. loss=0.574793	NNZ=304293
# [SparseLR] Training done (819.87s)
# [SparseLR] Model saved. To load, use name
# 		SparseLR_0
# ============================================================
# [2] Testing lr = 1.00e-04, l1_penalty = 1.00e-06, l2_penalty = 1.00e-03
# ============================================================
# [SparseLR] lr=0.0001 l1=1e-06 l2=0.001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.87s)	Avg. loss=0.757063	NNZ=304293
# [SparseLR] Epoch 25 (427.71s)	Avg. loss=0.558705	NNZ=304293
# [SparseLR] Epoch 49 (822.27s)	Avg. loss=0.471832	NNZ=304293
# [SparseLR] Training done (822.27s)
# [SparseLR] Model saved. To load, use name
# 		SparseLR_1
# ============================================================
# [3] Testing lr = 1.00e-03, l1_penalty = 1.00e-05, l2_penalty = 1.00e-05
# ============================================================
# [SparseLR] lr=0.001 l1=1e-05 l2=1e-05
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.42s)	Avg. loss=0.721848	NNZ=304293
# [SparseLR] Epoch 25 (423.83s)	Avg. loss=0.262598	NNZ=304293
# [SparseLR] Epoch 49 (815.20s)	Avg. loss=0.194522	NNZ=304293
# [SparseLR] Training done (815.20s)
# ============================================================
# [4] Testing lr = 1.00e-03, l1_penalty = 1.00e-06, l2_penalty = 1.00e-03
# ============================================================
# [SparseLR] lr=0.001 l1=1e-06 l2=0.001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.13s)	Avg. loss=0.729488	NNZ=304293
# [SparseLR] Epoch 25 (423.16s)	Avg. loss=0.299147	NNZ=304293
# [SparseLR] Epoch 49 (812.34s)	Avg. loss=0.260148	NNZ=304293
# [SparseLR] Training done (812.34s)
# ============================================================
# [5] Testing lr = 1.00e-02, l1_penalty = 1.00e-04, l2_penalty = 1.00e-05
# ============================================================
# [SparseLR] lr=0.01 l1=0.0001 l2=1e-05
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.46s)	Avg. loss=0.847230	NNZ=304293
# [SparseLR] Epoch 25 (425.78s)	Avg. loss=0.279197	NNZ=304293
# [SparseLR] Epoch 49 (816.58s)	Avg. loss=0.272634	NNZ=304293
# [SparseLR] Training done (816.58s)
# ============================================================
# [6] Testing lr = 1.00e-06, l1_penalty = 1.00e-03, l2_penalty = 1.00e-05
# ============================================================
# [SparseLR] lr=1e-06 l1=0.001 l2=1e-05
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.41s)	Avg. loss=0.993682	NNZ=304293
# [SparseLR] Epoch 25 (423.18s)	Avg. loss=0.984090	NNZ=304293
# [SparseLR] Epoch 49 (814.18s)	Avg. loss=0.975377	NNZ=304293
# [SparseLR] Training done (814.18s)
# [SparseLR] Model saved. To load, use name
# 		SparseLR_5
# ============================================================
# [7] Testing lr = 1.00e-06, l1_penalty = 1.00e-03, l2_penalty = 1.00e-02
# ============================================================
# [SparseLR] lr=1e-06 l1=0.001 l2=0.01
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.24s)	Avg. loss=1.142353	NNZ=304293
# [SparseLR] Epoch 25 (424.12s)	Avg. loss=1.129952	NNZ=304293
# [SparseLR] Epoch 49 (814.74s)	Avg. loss=1.118551	NNZ=304293
# [SparseLR] Training done (814.74s)
# [SparseLR] Model saved. To load, use name
# 		SparseLR_6
# ============================================================
# [8] Testing lr = 1.00e-02, l1_penalty = 1.00e-05, l2_penalty = 1.00e-02
# ============================================================
# [SparseLR] lr=0.01 l1=1e-05 l2=0.01
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.31s)	Avg. loss=0.859267	NNZ=304293
# [SparseLR] Epoch 25 (420.72s)	Avg. loss=0.664316	NNZ=304293
# [SparseLR] Epoch 49 (810.51s)	Avg. loss=0.670038	NNZ=304293
# [SparseLR] Training done (810.51s)
# ============================================================
# [9] Testing lr = 1.00e-04, l1_penalty = 1.00e-02, l2_penalty = 1.00e-06
# ============================================================
# [SparseLR] lr=0.0001 l1=0.01 l2=1e-06
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.24s)	Avg. loss=2.973371	NNZ=304293
# [SparseLR] Epoch 25 (423.09s)	Avg. loss=0.965605	NNZ=304293
# [SparseLR] Epoch 49 (813.39s)	Avg. loss=0.746057	NNZ=304293
# [SparseLR] Training done (813.39s)
# ============================================================
# [10] Testing lr = 1.00e-06, l1_penalty = 1.00e-05, l2_penalty = 1.00e-03
# ============================================================
# [SparseLR] lr=1e-06 l1=1e-05 l2=0.001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.22s)	Avg. loss=0.765533	NNZ=304293
# [SparseLR] Epoch 25 (421.66s)	Avg. loss=0.761074	NNZ=304293
# [SparseLR] Epoch 49 (810.33s)	Avg. loss=0.756922	NNZ=304293
# [SparseLR] Training done (810.33s)
# ============================================================
# [11] Testing lr = 1.00e-04, l1_penalty = 1.00e-02, l2_penalty = 1.00e-04
# ============================================================
# [SparseLR] lr=0.0001 l1=0.01 l2=0.0001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.60s)	Avg. loss=2.979214	NNZ=304293
# [SparseLR] Epoch 25 (420.69s)	Avg. loss=0.965072	NNZ=304293
# [SparseLR] Epoch 49 (809.66s)	Avg. loss=0.745342	NNZ=304293
# [SparseLR] Training done (809.66s)
# ============================================================
# [12] Testing lr = 1.00e-03, l1_penalty = 1.00e-06, l2_penalty = 1.00e-03
# ============================================================
# [SparseLR] lr=0.001 l1=1e-06 l2=0.001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.75s)	Avg. loss=0.727293	NNZ=304293
# [SparseLR] Epoch 25 (422.95s)	Avg. loss=0.301312	NNZ=304293
# [SparseLR] Epoch 49 (810.86s)	Avg. loss=0.262081	NNZ=304293
# [SparseLR] Training done (810.86s)
# ============================================================
# [13] Testing lr = 1.00e-04, l1_penalty = 1.00e-04, l2_penalty = 1.00e-05
# ============================================================
# [SparseLR] lr=0.0001 l1=0.0001 l2=1e-05
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.23s)	Avg. loss=0.758394	NNZ=304293
# [SparseLR] Epoch 25 (420.76s)	Avg. loss=0.560746	NNZ=304293
# [SparseLR] Epoch 49 (808.54s)	Avg. loss=0.474423	NNZ=304293
# [SparseLR] Training done (808.54s)
# ============================================================
# [14] Testing lr = 1.00e-03, l1_penalty = 1.00e-05, l2_penalty = 1.00e-04
# ============================================================
# [SparseLR] lr=0.001 l1=1e-05 l2=0.0001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.39s)	Avg. loss=0.727873	NNZ=304293
# [SparseLR] Epoch 25 (422.18s)	Avg. loss=0.270494	NNZ=304293
# [SparseLR] Epoch 49 (812.54s)	Avg. loss=0.206885	NNZ=304293
# [SparseLR] Training done (812.54s)
# ============================================================
# [15] Testing lr = 1.00e-04, l1_penalty = 1.00e-02, l2_penalty = 1.00e-05
# ============================================================
# [SparseLR] lr=0.0001 l1=0.01 l2=1e-05
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.28s)	Avg. loss=2.965711	NNZ=304293
# [SparseLR] Epoch 25 (422.67s)	Avg. loss=0.964118	NNZ=304293
# [SparseLR] Epoch 49 (814.00s)	Avg. loss=0.744938	NNZ=304293
# [SparseLR] Training done (814.00s)
# [SparseLR] Model saved. To load, use name
# 		SparseLR_14
# ============================================================
# [16] Testing lr = 1.00e-05, l1_penalty = 1.00e-06, l2_penalty = 1.00e-04
# ============================================================
# [SparseLR] lr=1e-05 l1=1e-06 l2=0.0001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.62s)	Avg. loss=0.750903	NNZ=304293
# [SparseLR] Epoch 25 (419.61s)	Avg. loss=0.711987	NNZ=304293
# [SparseLR] Epoch 49 (807.35s)	Avg. loss=0.683449	NNZ=304293
# [SparseLR] Training done (807.35s)
# ============================================================
# [17] Testing lr = 1.00e-06, l1_penalty = 1.00e-02, l2_penalty = 1.00e-03
# ============================================================
# [SparseLR] lr=1e-06 l1=0.01 l2=0.001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.26s)	Avg. loss=3.184560	NNZ=304293
# [SparseLR] Epoch 25 (421.80s)	Avg. loss=3.113331	NNZ=304293
# [SparseLR] Epoch 49 (809.24s)	Avg. loss=3.047173	NNZ=304293
# [SparseLR] Training done (809.24s)
# ============================================================
# [18] Testing lr = 1.00e-02, l1_penalty = 1.00e-05, l2_penalty = 1.00e-06
# ============================================================
# [SparseLR] lr=0.01 l1=1e-05 l2=1e-06
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.45s)	Avg. loss=0.835099	NNZ=304293
# [SparseLR] Epoch 25 (420.39s)	Avg. loss=0.213801	NNZ=304293
# [SparseLR] Epoch 49 (809.42s)	Avg. loss=0.210050	NNZ=304293
# [SparseLR] Training done (809.42s)
# ============================================================
# [19] Testing lr = 1.00e-05, l1_penalty = 1.00e-02, l2_penalty = 1.00e-06
# ============================================================
# [SparseLR] lr=1e-05 l1=0.01 l2=1e-06
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.31s)	Avg. loss=3.158967	NNZ=304293
# [SparseLR] Epoch 25 (419.22s)	Avg. loss=2.543110	NNZ=304293
# [SparseLR] Epoch 49 (805.77s)	Avg. loss=2.123594	NNZ=304293
# [SparseLR] Training done (805.77s)
# ============================================================
# [20] Testing lr = 1.00e-02, l1_penalty = 1.00e-05, l2_penalty = 1.00e-04
# ============================================================
# [SparseLR] lr=0.01 l1=1e-05 l2=0.0001
# [SparseLR] Building model
# [SparseLR] Training model
# [SparseLR] #examples=19366  #epochs=50  batch size=100
# [SparseLR] Epoch 0 (16.22s)	Avg. loss=0.831629	NNZ=304293
# [SparseLR] Epoch 25 (418.41s)	Avg. loss=0.250777	NNZ=304293
# [SparseLR] Epoch 49 (806.16s)	Avg. loss=0.244947	NNZ=304293
# [SparseLR] Training done (806.16s)
# INFO:tensorflow:Restoring parameters from ./SparseLR_14-0
# [SparseLR] Loaded model <SparseLR_14>
#           lr  l1_penalty  l2_penalty     Prec.      Rec.        F1
# 14  0.000100    0.010000    0.000010  0.406114  0.688039  0.510755
# 6   0.000001    0.001000    0.010000  0.405405  0.610358  0.487205
# 5   0.000001    0.001000    0.000010  0.407027  0.585697  0.480283
# 7   0.010000    0.000010    0.010000  0.395690  0.565968  0.465753
# 8   0.000100    0.010000    0.000001  0.398246  0.559803  0.465402
# 10  0.000100    0.010000    0.000100  0.385553  0.546239  0.452041
# 1   0.000100    0.000001    0.001000  0.379747  0.554871  0.450902
# 18  0.000010    0.010000    0.000001  0.394737  0.517879  0.448000
# 19  0.010000    0.000010    0.000100  0.400585  0.506782  0.447469
# 12  0.000100    0.000100    0.000010  0.384615  0.530210  0.445827
# 11  0.001000    0.000001    0.001000  0.394662  0.510481  0.445161
# 3   0.001000    0.000001    0.001000  0.396300  0.501850  0.442873
# 16  0.000001    0.010000    0.001000  0.391931  0.503083  0.440605
# 17  0.010000    0.000010    0.000001  0.396450  0.495684  0.440548
# 0   0.010000    0.001000    0.000100  0.396414  0.490752  0.438567
# 15  0.000010    0.000001    0.000100  0.390338  0.498150  0.437703
# 2   0.001000    0.000010    0.000010  0.387674  0.480888  0.429279
# 13  0.001000    0.000010    0.000100  0.384933  0.459926  0.419101
# 4   0.010000    0.000100    0.000010  0.393209  0.442663  0.416473
# 9   0.000001    0.000010    0.001000  0.367140  0.446363  0.402894

# %% [markdown]
# Note that to train a model without tuning any hyperparameters (at your own risk) just use the train method of the discriminative model. For instance, to train with 20 epochs and a learning rate of 0.001, you could run:
# disc_model.train(F_train, train_marginals, n_epochs=20, lr=0.001)
# We can analyze the learned model by examining the weights. For example, we can print out the features with the highest weights.

# %%
w, _ = disc_model.get_weights()
largest_idxs = reversed(np.argsort(np.abs(w))[-5:])
for i in largest_idxs:
    print 'Feature: {0: <70}Weight: {1:.6f}'.format(F_train.get_key(session, i).name, w[i])
# Out:
# Feature: TDL_LEMMA:LEFT-OF-MENTION[not the]                                    Weight: -0.362161
# Feature: TDL_LEMMA:BETWEEN-MENTION-and-MENTION[residue]                        Weight: 0.323048
# Feature: TDL_INV_LEMMA:RIGHT-OF-MENTION[seedling]                              Weight: -0.305459
# Feature: TDL_INV_LEMMA:BETWEEN-MENTION-and-MENTION[perform stain acetocarmine] Weight: -0.301503
# Feature: TDL_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dobj advcl nmod]            Weight: 0.298759

# %% [markdown]
# In this last section of the tutorial, we'll get the score we've been after: the performance of the extraction model on the blind test set (split 2). First, we load the test set labels and gold candidates we made in Part III.

# %%
from snorkel.annotations import load_gold_labels
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)

# %% [markdown]
# Now, we score using the discriminative model:

# %%
dtp, dfp, dtn, dfn = disc_model.score(session, F_test, L_gold_test)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.717
# Neg. class accuracy: 0.354
# Precision            0.44
# Recall               0.717
# F1                   0.546
# ----------------------------------------
# TP: 599 | FP: 762 | TN: 417 | FN: 236
# ========================================

# %% [markdown]
# Note that if this is the final test set that you will be reporting final numbers on, to avoid biasing results you should not inspect results. However you can run the model on your development set and, as we did in the previous part with the generative labeling function model, inspect examples to do error analysis.

# %% [markdown]
# # Thomas's Code
# ## `DDLiteModel` objects and feature generation
# We'll then create a `DDLiteModel` object for our extracted gene candidates. This lets us iterate with our model and labeling functions. Since `Entities` object defines a feature generation method, features are automatically created when we initialize a `DDLiteModel` object. These are generic features from the NLP markup and dependency tree in the neighborhood of the mention. Alternatively, you can define a custom feature set as a NumPy array or a Scipy sparse matrix. Here, we pickle our feature matrix so we don't have to recompute it in the future.

# %%
feats = None

pkl_f = 'gene_tag_example/gene_tag_feats_v1.pkl'
try:
    with open(pkl_f, 'rb') as f:
        feats = cPickle.load(f)
except:
    # %time E.extract_features()
    with open(pkl_f, 'w+') as f:
        cPickle.dump(E.feats, f)

DDL = DDLiteModel(E, feats)
print "Extracted {} features for each of {} mentions".format(DDL.num_feats(), DDL.num_candidates())

# %% [markdown]
# We need a blind, gold standard ground truth set to evaluate our predictions. We can add these by using the uids for the candidates we want, and align these with a value of 1 for positive or a value of -1 for negative. We'll load in a set now using `DDL.update_gt()` and set it as the holdout. We'll assign half of the holdout to a validation set for parameter tuning, and the other half to a test set.

# %%
with open('gene_tag_example/gt/uids.pkl', 'rb') as f:
    uids = cPickle.load(f)
with open('gene_tag_example/gt/gt.pkl', 'rb') as f:
    gt = cPickle.load(f)
    
DDL.update_gt(gt[:50], uids=uids[:50])
DDL.set_holdout(validation_frac=0.5)

# %% [markdown]
# ## Building a ground truth set with MindTagger
# In order to evaluate our labeling functions and learning results, we'll create a small set of ground truth labels for some candidates using [Mindtagger](http://deepdive.stanford.edu/labeling). This will highlight each candidate in the sentence in which it appears. We set the response to yes if it is a mention of gene, and no otherwise. If you aren't sure, you can abstain from labeling. In a real application, we would likely want to tag more than 20 candidates.

# %%
DDL.open_mindtagger(num_sample=100, width='100%', height=1200)

# %% [markdown]
# Now, we'll retrieve the tags and add them to our `DDLiteModel`. We can also use a previously defined Mindtagger label set, similar to how we added our gold labels (this time, we'll use indexes instead of uids). These labels are used for evaluating our labeling functions against the *development set*.

# %%
DDL.add_mindtagger_tags()

# %%
DDL.update_gt(gt[50:], uids=uids[50:])

# %% [markdown]
# ## Writing labeling functions
# We'll use data programming to learn a logistic regression model which will predict the probability of a candidate entity being a true gene mention. Since our training data is not manually labeled, we'll generate many (potentially noisy) labels as a surrogate for precise, manual labels. Feature extraction and model learning are very simple in ddlite. Writing labeling functions is where the real artistry comes in. One of ddlite's goals is to enable rapid prototyping, debugging, and experimenting with labeling functions. These can be used either to create a simple standalone app, or to plug into DeepDive. Labeling functions, or LFs, are functions that take an `Candidate` object. They must return 1 (for a positive label), 0 (for abstaining), or -1 (for a negative example). For now, we'll write a few simple LFs to get started:
#
# * The first, second, and third LFs return a positive label if the lemma "gene", "mutant", or "express" appear in a window around the mention, respectively
# * The third LF returns a positive label if the dependency parent of any of the words in the mention is "mutation", and abstains otherwise
# * The fourth, fifth, and sixth LF return a negative label if the mention candidate contains "DNA", "RNA", or "SNP" respectively (these are common uppercase nouns which are not genes)

# %%
def LF_gene(m):
    return 1 if ('gene' in m.post_window('lemmas')) or ('gene' in m.pre_window('lemmas')) else 0
def LF_gene_dp(m):
    return 1 if 'gene' in [m.lemmas[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_genotype_dp(m):
    return 1 if 'genotype' in [m.lemmas[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_mutant(m):
    return 1 if ('mutant' in m.post_window('lemmas')) or ('mutant' in m.pre_window('lemmas')) else 0
def LF_variant(m):
    return 1 if ('variant' in m.post_window('lemmas')) or ('variant' in m.pre_window('lemmas')) else 0
def LF_express(m):
    return 1 if ('express' in m.post_window('lemmas')) or ('express' in m.pre_window('lemmas')) else 0
def LF_mutation(m):
    return 1 if 'mutation' in [m.lemmas[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_JJ(m):
    return 1 if 'JJ' in m.post_window('poses') else 0
def LF_IN(m):
    return 1 if 'IN' in m.pre_window('poses', 1) else 0

def LF_dna(m):
    return -1 if 'DNA' in m.mention('words') else 0
def LF_rna(m):
    return -1 if 'RNA' in m.mention('words') else 0
def LF_snp(m):
    return -1 if 'SNP' in m.mention('words') else 0
def LF_protein(m):
    return -1 if 'protein' in m.pre_window('lemmas') else 0
def LF_LRB(m):
    return -1 if '-LRB-' in m.post_window('poses', 1) else 0
def LF_RRB(m):
    return -1 if '-RRB-' in m.post_window('poses', 1) else 0
def LF_dev_dp(m):
    return -1 if 'development' in [m.lemmas[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_protein_dp(m):
    return -1 if 'protein' in [m.lemmas[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_network_dp(m):
    return -1 if 'network' in [m.lemmas[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_JJ_dp(m):
    return -1 if 'JJ' in [m.poses[m.dep_parents[i] - 1] for i in m.idxs] else 0
def LF_NNP(m):
    return -1 if 'NNP' in m.mention('poses') else 0

# %% [markdown]
# Our intuition is that the few simple LFs given above won't yield a good model. We'll see this more concretely when we evaluate the labeling functions. For now, let's leave them as is. After writing the LFs, we simply collect them and apply them to mentions. If we define more LFs later, we can apply them incrementally or overwrite all the LFs so far.

# %%
LFs = [LF_JJ, LF_JJ_dp, LF_NNP, LF_RRB, LF_dev_dp, LF_dna, LF_express, LF_gene, LF_gene_dp,
       LF_genotype_dp, LF_mutant, LF_mutation, LF_network_dp, LF_protein, LF_protein_dp,
       LF_rna, LF_snp, LF_variant, LF_IN, LF_LRB]
DDL.apply_lfs(LFs, clear=False)

# %% [markdown]
# We'll use ddlite's LF assessment utilities to debug and analyze our LFs before running inference. First, we'll generate summary plots which show the following:
#
# * Do the LFs cover the data well or do we have many candidates for which all of the LFs abstained?
# * Is there overlap between the LFs? Do many return positive or negative labels for the same candidate?
# * Do the LFs conflict with each other? Do candidates tend to have many of one type of label, or a mix?

# %%
DDL.print_lf_stats()

# %%
DDL.plot_lf_stats()

# %% [markdown]
# As we may expect, the few LFs do not cover the data very well. We can switch to an LF view of these measures and show tables for the LFs with the most conflict, lowest coverage, and lowest empirical accuracy as compared to the development set labels.

# %%
DDL.top_conflict_lfs(n=3)

# %%
DDL.lowest_coverage_lfs(n=3)

# %%
DDL.lowest_empirical_accuracy_lfs(n=10)

# %%
DDL.lf_summary_table()

# %% [markdown]
# Since our development set is small, we can't evaluate LF performance particularly well. If we observe LFs with very low accuracy, poor generalization, and a sufficiently large sample size, this could be an indication that the LF is buggy.

# %% [markdown]
# ## Learning
# To learn weights for the features and LFs, we use a simple, regularized logistic regression model. Again, the results won't be meaningful without more LFs. We'll tell ddlite to log the results and print out a summary table

# %%
matplotlib.rcParams['figure.figsize'] = (12,4)
mu_seq = np.ravel([1e-9, 1e-5, 1e-3, 1e-1])
lf_opts = {'sample': False, 'verbose': True}
model_opts = {'sample': False, 'n_iter': 3000, 'alpha': 0.5, 'mu': mu_seq, 'bias': False, 'verbose': True}
# %time DDL.train_model(method='lr', lf_opts=lf_opts, model_opts=model_opts)

# %% [markdown]
# We can use [DeepDive-style calibration plots](http://deepdive.stanford.edu/calibration) to evaluate the quality of our predictions.

# %%
DDL.plot_calibration()

# %% [markdown]
# Since we used pipeline learning, we can also see the gain in accuracy we got from using features and not just LFs as a collection of rules.

# %%
idxs, gt = DDL.get_labeled_ground_truth(subset=DDL.holdout())
acc_feats = np.mean(DDL.get_predicted(subset=DDL.holdout()) == gt)
acc_lfs = np.mean(DDL.get_lf_predicted(subset=DDL.holdout()) == gt)
print "LF accuracy: {:.3f}\nFull model accuracy: {:.3f}".format(acc_lfs, acc_feats)

# %% [markdown]
# ## Iterating with labeling functions
# After analyzing our LFs and obtaining model results, we can revise our LF set. We can see all of the results thus far, and reopen MindTagger to see some mentions that aren't currently covered by LFs.

# %%
DDL.show_log()

# %%
DDL.open_mindtagger(width='100%', height=1200, abstain=True)

# %% [markdown]
# In order to use LSTM to learn weights, we just just call the following functions.

# %%
lf_opts = {'sample': False, 'verbose': True}
model_opts = {'n_iter': 300, 'verbose': True, 'contain_mention': True, 'word_window_length': 0, 'ignore_case': False}
# %time DDL.train_model(method='lstm', lf_opts=lf_opts, model_opts=model_opts)

# %%
idxs, gt = DDL.get_labeled_ground_truth(subset=DDL.holdout())
acc_feats = np.mean(DDL.get_predicted(subset=DDL.holdout()) == gt)
print "Full model accuracy: {:.3f}".format(acc_feats)
